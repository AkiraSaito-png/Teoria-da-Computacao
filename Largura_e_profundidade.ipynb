# %%
import networkx as nx
import matplotlib.pyplot as plt

#Criação do grafo não direcionado
G.add_node("A")
G.add_node("B")
G.add_node("C")
G.add_node("D")
G.add_node("E")
G.add_node("F")
G.add_edge("A","B", weight = 12.5 )
G.add_edge("A","C", weight = 8.3 )
G.add_edge("C","D", weight = 5.2 )
G.add_edge("C","E", weight = 9.7 )
G.add_edge("C","F", weight = 2.3 )
G.add_edge("A","D", weight = 7.4 )

#Retorno de largura
L = nx.bfs_tree(G, "A")

#Retorno de Profundidade
P = nx.dfs_tree(G, "A")

#Layouts
lay2 = nx.shell_layout(L)
lay3 = nx.shell_layout(P)

#Plotar os grafos
plt.figure(figsize=(18, 12))

plt.subplot(232),
nx.draw_networkx_nodes(L,lay2,node_size=1000)
nx.draw_networkx_edges(L,lay2,width=1)
nx.draw_networkx_labels(L,lay2)
plt.title('Largura')

plt.subplot(233),
nx.draw_networkx_nodes(P,lay3,node_size=1000)
nx.draw_networkx_edges(P,lay3,width=1)
nx.draw_networkx_labels(P,lay3)
plt.title('Altura')

plt.show()
